# %%
import os, re
import glob
import matplotlib.pyplot as plt
import numpy as np
from collections import OrderedDict

# %%
class Preprocessor:
    def __init__(self, output_path):
        self.output_path = output_path
        self.output_file = None
        self.line_count = 0
        self.file_count = 0
        self.code_ident = ["((", "))", "{{", "}}",  "[[",  "]]",  "::", ":="]
        self.html_tags = ["<img", "<input type", "<p>", "<br>"]
        self.line_per_docsite = {} #number of lines in spec/website
        self.word_per_docsite = {} #number of words in spec/website
        self.line_per_spec = {} #number of lines per spec file
        self.spec_per_rel = {} #number of spec file per release
        
        
    def processAll(self, input_path):
        #input_path is a directory containing raw data
        
        self.file_count = 0
        output_file_path = os.path.join(self.output_path,'processed_5G.txt')
        
        if os.path.exists(output_file_path):
            with open(output_file_path, 'r') as fp:
                self.line_count = len(fp.readlines()) #To get the next sequence number, as we are appending
            
        self.output_file = open(output_file_path,'a')
        
        for file in glob.glob(input_path + '/**/*.txt', recursive=True):
            #if file.endswith(".txt"):
            file_path = os.path.join(input_path,file)
            self.processIt(file_path, [1])
            
        self.output_file.close()
    
    def processIt(self, file, task:list):
        
        #Count specs per release
        if file.split('/')[5][:3] == "Rel":
            key = file.split('/')[5]
            if key in self.spec_per_rel:
                self.spec_per_rel[key] += 1
            else:
                self.spec_per_rel[key] = 1
        
        isSpec = False
        section_at_next = True
        self.file_count += 1
        file_line_count = 0
        file_word_count = 0
        #file: path to a file
        with open(file) as f:
            text = f.readlines()
            for line in text:
                #print(line)
                
                if any(x in line for x in self.code_ident):
                    continue
                if any(x in line for x in self.html_tags):
                    continue
                if '\\' in line: #noisy data
                    continue
                #if 'Editor\'s Note' in line:
                #    continue
                if line.istitle(): #Title case: first letter of the first word capitalized- means it is a new sentence
                    self.output_file.write('\n')
                else: 
                    self.output_file.write(' ')
                line = re.sub(r'\[\d*?\]', '', line) #Citation removal
                line = re.sub(r'(as shown below|[Ss]ee figure below):*\-*', '', line) #remove certain strings
                line = re.sub('\(see [fF]igure .*?\d\)', '', line) #remove '(see Figure #)'
                line = re.sub('Figure .*?[\dA-Za-z]:', '', line) #Figure captions
                line = re.sub(r'(\d[A-Za-z]*\.)*\d[\.\-]\d?', '', line) #5.3.4.1 or 4.5.2-1 type number removal
                line = re.sub(r'\[pic\]', '', line) #picture alternative bad text removal
                #line = re.sub(r'\\+', '\\', line) #keep only one backslash
                line = re.sub(r'\\x[0-9a-fA-F]{2}', '', line) #removing '\xc#' type patterns
                
                
                line = re.sub(r'(\n)+', '', line) #remove extra newlines
                line = re.sub(r'(\t)+', ' ', line) #remove tabs
                line = re.sub(r'^[\.·\-]', '', line) #starting dot, interpunct, hyphen removal
                line = re.sub(r'^ ', '', line) #starting whitespace removal
                line = re.sub(r'[\.:,;\-]*$', '', line) #one or multiple dot, colon, hyphen, semicolon removal at the end
                line = re.sub(r'\|', '', line) #pipe generated from table
                line = re.sub(r' +', ' ', line) #multiple whitespace, keep one
                              
                if section_at_next is True:
                    line = re.sub(r'^\d.*', '', line) #remove lines with starting digits, meaning sections
                
                
                
                line = re.sub(r'([,;:])(\w)', r'\1 \2', line) #insert whitespace after punctuations, except fullstop, underscore
                                                              #hyphen
                line = re.sub(r'\ue000', '', line, re.UNICODE)
                
                
                
                line = re.sub(r'(\( )', '\(', line) #whitespace after opening paren.
                line = re.sub(r'( \))', '\)', line) #whitespace before closing paren.
                line = re.sub(r'(\(\))|(\[\])|(\{\})', '', line) #remove empty paren, curly-braces, brackets
                line = re.sub(r'^(TS \d\d\d?)|^(TR \d\d\d?)', 'Specification document', line)
                line = re.sub(r'(TS \d\d\d?)|(TR \d\d\d?)', 'specification document', line)
                
                if len(line.split()) < 4 : #skip the line
                    continue
                if sum(c.isdigit() for c in line)/len(line) >= 0.2: #More than 20% characters of the line are digits
                    continue
                if re.search(r'(C\(\d\d\d\))', line):
                    continue
                if re.search(r'% %', line):
                    continue
                if re.search(r'-?\d,? -?\d,? -?\d,? -?\d', line): #paterns like -1, 1, 1 1 etc.
                    continue
                if re.search(r'-?[A-Za-z],? -?[A-Za-z],? -?[A-Za-z]', line): #paterns like -1, 1, 1 1 etc.
                    continue
                
                if line[-2:] == 'TS' or line[:-2] == 'TR':
                    section_at_next = False
                else:
                    section_at_next = True
                    
                #line = line + '.'
                
                if line != '' and line != '.':
                    line_set = line.split('. ') #Some lines still have multiple sentences
                    for i, sentence in enumerate(line_set):
                        self.line_count += 1
                        file_line_count += 1
                        file_word_count += len(sentence.split())
                        if i != len(line_set)-1:
                            
                            self.output_file.write(sentence + '.\n')
                        else:
                            self.output_file.write(sentence)
            #end of document
            self.output_file.write('\n')
            print(str(self.file_count)+ " file(s) completed. Lines added: " + str(file_line_count))
            
            if file.split('/')[5][:3] == "Rel":
                key = 'spec'
                isSpec = True
            if file.split('/')[-4] == "Dataset_L1" or file.split('/')[5][:3] == 'web':
                key = file.split('/')[-2] #Name of the website
                isSpec = False
            if key in self.line_per_docsite:
                self.line_per_docsite[key] += file_line_count
            else:
                self.line_per_docsite[key] = file_line_count
                
            if key in self.word_per_docsite:
                self.word_per_docsite[key] += file_word_count
            else:
                self.word_per_docsite[key] = file_word_count
            
            if isSpec:
                key = file_line_count
                if key in self.line_per_spec:
                    self.line_per_spec[key] += 1
                else:
                    self.line_per_spec[key] = 1
            
            print("\n---------------------------------------------------------------------------------------------\n")
        #task is a list of preprocessing tasks you want to carry on

# %%
input_path = "/scratch/gilbreth/rahman75/raw_data/" #all inputs
input_path_2 = "/home/rahman75/Scrap/Dataset_L1"
#input_path = "/home/rahman75/Preprocessing/raw" #demo inputs
output_path = "/scratch/gilbreth/rahman75/gold_data"
#raw_data_path = ["spec","web"]

# %% [markdown]
# ### Outputs

# %%
dataProcessor = Preprocessor(output_path)
dataProcessor.processAll(input_path)
dataProcessor.processAll(input_path_2)
# Out:
# 1 file(s) completed. Lines added: 576
#
# ---------------------------------------------------------------------------------------------
#
# 2 file(s) completed. Lines added: 464
#
# ---------------------------------------------------------------------------------------------
#
# 3 file(s) completed. Lines added: 350
#
# ---------------------------------------------------------------------------------------------
#
# 4 file(s) completed. Lines added: 1576
#
# ---------------------------------------------------------------------------------------------
#
# 5 file(s) completed. Lines added: 402
#
# ---------------------------------------------------------------------------------------------
#
# 6 file(s) completed. Lines added: 186
#
# ---------------------------------------------------------------------------------------------
#
# 7 file(s) completed. Lines added: 244
#
# ---------------------------------------------------------------------------------------------
#
# 8 file(s) completed. Lines added: 7621
#
# ---------------------------------------------------------------------------------------------
#
# 9 file(s) completed. Lines added: 2726
#
# ---------------------------------------------------------------------------------------------
#
# 10 file(s) completed. Lines added: 1065
#
# ---------------------------------------------------------------------------------------------
#
# 11 file(s) completed. Lines added: 7559
#
# ---------------------------------------------------------------------------------------------
#
# 12 file(s) completed. Lines added: 2429
#
# ---------------------------------------------------------------------------------------------
#
# 13 file(s) completed. Lines added: 705
#
# ---------------------------------------------------------------------------------------------
#
# 14 file(s) completed. Lines added: 393
#
# ---------------------------------------------------------------------------------------------
#
# 15 file(s) completed. Lines added: 379
#
# ---------------------------------------------------------------------------------------------
#
# 16 file(s) completed. Lines added: 1699
#
# ---------------------------------------------------------------------------------------------
#
# 17 file(s) completed. Lines added: 797
#
# ---------------------------------------------------------------------------------------------
#
# 18 file(s) completed. Lines added: 438
#
# ---------------------------------------------------------------------------------------------
#
# 19 file(s) completed. Lines added: 332
#
# ---------------------------------------------------------------------------------------------
#
# 20 file(s) completed. Lines added: 334
#
# ---------------------------------------------------------------------------------------------
#
# 21 file(s) completed. Lines added: 834
#
# ---------------------------------------------------------------------------------------------
#
# 22 file(s) completed. Lines added: 2127
#
# ---------------------------------------------------------------------------------------------
#
# 23 file(s) completed. Lines added: 2024
#
# ---------------------------------------------------------------------------------------------
#
# 24 file(s) completed. Lines added: 748
#
# ---------------------------------------------------------------------------------------------
#
# 25 file(s) completed. Lines added: 1016
#
# ---------------------------------------------------------------------------------------------
#
# 26 file(s) completed. Lines added: 649
#
# ---------------------------------------------------------------------------------------------
#
# 27 file(s) completed. Lines added: 178
#
# ---------------------------------------------------------------------------------------------
#
# 28 file(s) completed. Lines added: 807
#
# ---------------------------------------------------------------------------------------------
#
# 29 file(s) completed. Lines added: 708
#
# ---------------------------------------------------------------------------------------------
#
# 30 file(s) completed. Lines added: 897
#
# ---------------------------------------------------------------------------------------------
#
# 31 file(s) completed. Lines added: 487
#
# ---------------------------------------------------------------------------------------------
#
# 32 file(s) completed. Lines added: 913
#
# ---------------------------------------------------------------------------------------------
#
# 33 file(s) completed. Lines added: 1142
#
# ---------------------------------------------------------------------------------------------
#
# 34 file(s) completed. Lines added: 1072
#
# ---------------------------------------------------------------------------------------------
#
# 35 file(s) completed. Lines added: 2542
#
# ---------------------------------------------------------------------------------------------
#
# 36 file(s) completed. Lines added: 569
#
# ---------------------------------------------------------------------------------------------
#
# 37 file(s) completed. Lines added: 12683
#
# ---------------------------------------------------------------------------------------------
#
# 38 file(s) completed. Lines added: 4385
#
# ---------------------------------------------------------------------------------------------
#
# 39 file(s) completed. Lines added: 3763
#
# ---------------------------------------------------------------------------------------------
#
# 40 file(s) completed. Lines added: 351
#
# ---------------------------------------------------------------------------------------------
#
# 41 file(s) completed. Lines added: 676
#
# ---------------------------------------------------------------------------------------------
#
# 42 file(s) completed. Lines added: 6545
#
# ---------------------------------------------------------------------------------------------
#
# 43 file(s) completed. Lines added: 2940
#
# ---------------------------------------------------------------------------------------------
#
# 44 file(s) completed. Lines added: 875
#
# ---------------------------------------------------------------------------------------------
#
# 45 file(s) completed. Lines added: 1139
#
# ---------------------------------------------------------------------------------------------
#
# 46 file(s) completed. Lines added: 993
#
# ---------------------------------------------------------------------------------------------
#
# 47 file(s) completed. Lines added: 573
#
# ---------------------------------------------------------------------------------------------
#
# 48 file(s) completed. Lines added: 9593
#
# ---------------------------------------------------------------------------------------------
#
# 49 file(s) completed. Lines added: 1523
#
# ---------------------------------------------------------------------------------------------
#
# 50 file(s) completed. Lines added: 352
#
# ---------------------------------------------------------------------------------------------
#
# 51 file(s) completed. Lines added: 760
#
# ---------------------------------------------------------------------------------------------
#
# 52 file(s) completed. Lines added: 935
#
# ---------------------------------------------------------------------------------------------
#
# 53 file(s) completed. Lines added: 4628
#
# ---------------------------------------------------------------------------------------------
#
# 54 file(s) completed. Lines added: 1816
#
# ---------------------------------------------------------------------------------------------
#
# 55 file(s) completed. Lines added: 1320
#
# ---------------------------------------------------------------------------------------------
#
# 56 file(s) completed. Lines added: 6778
#
# ---------------------------------------------------------------------------------------------
#
# 57 file(s) completed. Lines added: 1204
#
# ---------------------------------------------------------------------------------------------
#
# 58 file(s) completed. Lines added: 236
#
# ---------------------------------------------------------------------------------------------
#
# 59 file(s) completed. Lines added: 232
#
# ---------------------------------------------------------------------------------------------
#
# 60 file(s) completed. Lines added: 540
#
# ---------------------------------------------------------------------------------------------
#
# 61 file(s) completed. Lines added: 687
#
# ---------------------------------------------------------------------------------------------
#
# 62 file(s) completed. Lines added: 476
#
# ---------------------------------------------------------------------------------------------
#
# 63 file(s) completed. Lines added: 634
#
# ---------------------------------------------------------------------------------------------
# 64 file(s) completed. Lines added: 299
#
# ---------------------------------------------------------------------------------------------
#
# 65 file(s) completed. Lines added: 110
#
# ---------------------------------------------------------------------------------------------
#
# 66 file(s) completed. Lines added: 1528
#
# ---------------------------------------------------------------------------------------------
#
# 67 file(s) completed. Lines added: 520
#
# ---------------------------------------------------------------------------------------------
#
# 68 file(s) completed. Lines added: 180
#
# ---------------------------------------------------------------------------------------------
#
# 69 file(s) completed. Lines added: 176
#
# ---------------------------------------------------------------------------------------------
#
# 70 file(s) completed. Lines added: 473
#
# ---------------------------------------------------------------------------------------------
#
# 71 file(s) completed. Lines added: 351
#
# ---------------------------------------------------------------------------------------------
#
# 72 file(s) completed. Lines added: 212
#
# ---------------------------------------------------------------------------------------------
#
# 73 file(s) completed. Lines added: 868
#
# ---------------------------------------------------------------------------------------------
#
# 74 file(s) completed. Lines added: 3000
#
# ---------------------------------------------------------------------------------------------
#
# 75 file(s) completed. Lines added: 3785
#
# ---------------------------------------------------------------------------------------------
#
# 76 file(s) completed. Lines added: 333
#
# ---------------------------------------------------------------------------------------------
#
# 77 file(s) completed. Lines added: 1713
#
# ---------------------------------------------------------------------------------------------
#
# 78 file(s) completed. Lines added: 2838
#
# ---------------------------------------------------------------------------------------------
#
# 79 file(s) completed. Lines added: 332
#
# ---------------------------------------------------------------------------------------------
#
# 80 file(s) completed. Lines added: 3311
#
# ---------------------------------------------------------------------------------------------
#
# 81 file(s) completed. Lines added: 1395
#
# ---------------------------------------------------------------------------------------------
#
# 82 file(s) completed. Lines added: 137
#
# ---------------------------------------------------------------------------------------------
#
# 83 file(s) completed. Lines added: 373
#
# ---------------------------------------------------------------------------------------------
#
# 84 file(s) completed. Lines added: 2618
#
# ---------------------------------------------------------------------------------------------
#
# 85 file(s) completed. Lines added: 1256
#
# ---------------------------------------------------------------------------------------------
#
# 86 file(s) completed. Lines added: 1053
#
# ---------------------------------------------------------------------------------------------
#
# 87 file(s) completed. Lines added: 1300
#
# ---------------------------------------------------------------------------------------------
#
# 88 file(s) completed. Lines added: 551
#
# ---------------------------------------------------------------------------------------------
#
# 89 file(s) completed. Lines added: 5948
#
# ---------------------------------------------------------------------------------------------
#
# 90 file(s) completed. Lines added: 1598
#
# ---------------------------------------------------------------------------------------------
#
# 91 file(s) completed. Lines added: 1810
#
# ---------------------------------------------------------------------------------------------
#
# 92 file(s) completed. Lines added: 502
#
# ---------------------------------------------------------------------------------------------
#
# 93 file(s) completed. Lines added: 1337
#
# ---------------------------------------------------------------------------------------------
#
# 94 file(s) completed. Lines added: 714
#
# ---------------------------------------------------------------------------------------------
#
# 95 file(s) completed. Lines added: 12190
#
# ---------------------------------------------------------------------------------------------
#
# 96 file(s) completed. Lines added: 2509
#
# ---------------------------------------------------------------------------------------------
#
# 97 file(s) completed. Lines added: 1070
#
# ---------------------------------------------------------------------------------------------
#
# 98 file(s) completed. Lines added: 267
#
# ---------------------------------------------------------------------------------------------
#
# 99 file(s) completed. Lines added: 3614
#
# ---------------------------------------------------------------------------------------------
#
# 100 file(s) completed. Lines added: 3616
#
# ---------------------------------------------------------------------------------------------
#
# 101 file(s) completed. Lines added: 2308
#
# ---------------------------------------------------------------------------------------------
#
# 102 file(s) completed. Lines added: 2763
#
# ---------------------------------------------------------------------------------------------
#
# 103 file(s) completed. Lines added: 1723
#
# ---------------------------------------------------------------------------------------------
#
# 104 file(s) completed. Lines added: 667
#
# ---------------------------------------------------------------------------------------------
#
# 105 file(s) completed. Lines added: 1032
#
# ---------------------------------------------------------------------------------------------
#
# 106 file(s) completed. Lines added: 4547
#
# ---------------------------------------------------------------------------------------------
#
# 107 file(s) completed. Lines added: 1515
#
# ---------------------------------------------------------------------------------------------
#
# 108 file(s) completed. Lines added: 676
#
# ---------------------------------------------------------------------------------------------
#
# 109 file(s) completed. Lines added: 664
#
# ---------------------------------------------------------------------------------------------
#
# 110 file(s) completed. Lines added: 196
#
# ---------------------------------------------------------------------------------------------
#
# 111 file(s) completed. Lines added: 306
#
# ---------------------------------------------------------------------------------------------
#
# 112 file(s) completed. Lines added: 1342
#
# ---------------------------------------------------------------------------------------------
#
# 113 file(s) completed. Lines added: 1347
#
# ---------------------------------------------------------------------------------------------
#
# 114 file(s) completed. Lines added: 1873
#
# ---------------------------------------------------------------------------------------------
#
# 115 file(s) completed. Lines added: 1808
#
# ---------------------------------------------------------------------------------------------
#
# 116 file(s) completed. Lines added: 204
#
# ---------------------------------------------------------------------------------------------
#
# 117 file(s) completed. Lines added: 2307
#
# ---------------------------------------------------------------------------------------------
#
# 118 file(s) completed. Lines added: 1197
#
# ---------------------------------------------------------------------------------------------
#
# 119 file(s) completed. Lines added: 2781
#
# ---------------------------------------------------------------------------------------------
#
# 120 file(s) completed. Lines added: 1107
#
# ---------------------------------------------------------------------------------------------
#
# 121 file(s) completed. Lines added: 997
#
# ---------------------------------------------------------------------------------------------
#
# 122 file(s) completed. Lines added: 1900
#
# ---------------------------------------------------------------------------------------------
#
# 123 file(s) completed. Lines added: 2040
#
# ---------------------------------------------------------------------------------------------
#
# 124 file(s) completed. Lines added: 2707
#
# ---------------------------------------------------------------------------------------------
# 125 file(s) completed. Lines added: 3875
#
# ---------------------------------------------------------------------------------------------
#
# 126 file(s) completed. Lines added: 4047
#
# ---------------------------------------------------------------------------------------------
#
# 127 file(s) completed. Lines added: 552
#
# ---------------------------------------------------------------------------------------------
#
# 128 file(s) completed. Lines added: 1712
#
# ---------------------------------------------------------------------------------------------
#
# 129 file(s) completed. Lines added: 665
#
# ---------------------------------------------------------------------------------------------
#
# 130 file(s) completed. Lines added: 928
#
# ---------------------------------------------------------------------------------------------
#
# 131 file(s) completed. Lines added: 4552
#
# ---------------------------------------------------------------------------------------------
#
# 132 file(s) completed. Lines added: 912
#
# ---------------------------------------------------------------------------------------------
#
# 133 file(s) completed. Lines added: 539
#
# ---------------------------------------------------------------------------------------------
#
# 134 file(s) completed. Lines added: 1887
#
# ---------------------------------------------------------------------------------------------
#
# 135 file(s) completed. Lines added: 191
#
# ---------------------------------------------------------------------------------------------
#
# 136 file(s) completed. Lines added: 529
#
# ---------------------------------------------------------------------------------------------
#
# 137 file(s) completed. Lines added: 374
#
# ---------------------------------------------------------------------------------------------
#
# 138 file(s) completed. Lines added: 887
#
# ---------------------------------------------------------------------------------------------
#
# 139 file(s) completed. Lines added: 432
#
# ---------------------------------------------------------------------------------------------
#
# 140 file(s) completed. Lines added: 3416
#
# ---------------------------------------------------------------------------------------------
#
# 141 file(s) completed. Lines added: 3709
#
# ---------------------------------------------------------------------------------------------
#
# 142 file(s) completed. Lines added: 1454
#
# ---------------------------------------------------------------------------------------------
#
# 143 file(s) completed. Lines added: 1968
#
# ---------------------------------------------------------------------------------------------
#
# 144 file(s) completed. Lines added: 1080
#
# ---------------------------------------------------------------------------------------------
#
# 145 file(s) completed. Lines added: 1752
#
# ---------------------------------------------------------------------------------------------
#
# 146 file(s) completed. Lines added: 719
#
# ---------------------------------------------------------------------------------------------
#
# 147 file(s) completed. Lines added: 524
#
# ---------------------------------------------------------------------------------------------
#
# 148 file(s) completed. Lines added: 2271
#
# ---------------------------------------------------------------------------------------------
#
# 149 file(s) completed. Lines added: 1077
#
# ---------------------------------------------------------------------------------------------
#
# 150 file(s) completed. Lines added: 139
#
# ---------------------------------------------------------------------------------------------
#
# 151 file(s) completed. Lines added: 1057
#
# ---------------------------------------------------------------------------------------------
#
# 152 file(s) completed. Lines added: 1166
#
# ---------------------------------------------------------------------------------------------
#
# 153 file(s) completed. Lines added: 2843
#
# ---------------------------------------------------------------------------------------------
#
# 154 file(s) completed. Lines added: 520
#
# ---------------------------------------------------------------------------------------------
#
# 155 file(s) completed. Lines added: 2744
#
# ---------------------------------------------------------------------------------------------
#
# 156 file(s) completed. Lines added: 1595
#
# ---------------------------------------------------------------------------------------------
#
# 157 file(s) completed. Lines added: 638
#
# ---------------------------------------------------------------------------------------------
#
# 158 file(s) completed. Lines added: 1309
#
# ---------------------------------------------------------------------------------------------
#
# 159 file(s) completed. Lines added: 565
#
# ---------------------------------------------------------------------------------------------
#
# 160 file(s) completed. Lines added: 1518
#
# ---------------------------------------------------------------------------------------------
#
# 161 file(s) completed. Lines added: 404
#
# ---------------------------------------------------------------------------------------------
#
# 162 file(s) completed. Lines added: 230
#
# ---------------------------------------------------------------------------------------------
#
# 163 file(s) completed. Lines added: 748
#
# ---------------------------------------------------------------------------------------------
#
# 164 file(s) completed. Lines added: 2684
#
# ---------------------------------------------------------------------------------------------
#
# 165 file(s) completed. Lines added: 1747
#
# ---------------------------------------------------------------------------------------------
#
# 166 file(s) completed. Lines added: 1343
#
# ---------------------------------------------------------------------------------------------
#
# 167 file(s) completed. Lines added: 690
#
# ---------------------------------------------------------------------------------------------
#
# 168 file(s) completed. Lines added: 679
#
# ---------------------------------------------------------------------------------------------
#
# 169 file(s) completed. Lines added: 4041
#
# ---------------------------------------------------------------------------------------------
#
# 170 file(s) completed. Lines added: 2091
#
# ---------------------------------------------------------------------------------------------
#
# 171 file(s) completed. Lines added: 4135
#
# ---------------------------------------------------------------------------------------------
#
# 172 file(s) completed. Lines added: 3982
#
# ---------------------------------------------------------------------------------------------
#
# 173 file(s) completed. Lines added: 639
#
# ---------------------------------------------------------------------------------------------
#
# 174 file(s) completed. Lines added: 2643
#
# ---------------------------------------------------------------------------------------------
#
# 175 file(s) completed. Lines added: 1357
#
# ---------------------------------------------------------------------------------------------
#
# 176 file(s) completed. Lines added: 1820
#
# ---------------------------------------------------------------------------------------------
#
# 177 file(s) completed. Lines added: 1819
#
# ---------------------------------------------------------------------------------------------
#
# 178 file(s) completed. Lines added: 592
#
# ---------------------------------------------------------------------------------------------
#
# 179 file(s) completed. Lines added: 2699
#
# ---------------------------------------------------------------------------------------------
#
# 180 file(s) completed. Lines added: 2270
#
# ---------------------------------------------------------------------------------------------
#
# 181 file(s) completed. Lines added: 3079
#
# ---------------------------------------------------------------------------------------------
#
# 182 file(s) completed. Lines added: 1409
#
# ---------------------------------------------------------------------------------------------
#
# 183 file(s) completed. Lines added: 763
#
# ---------------------------------------------------------------------------------------------
#
# 184 file(s) completed. Lines added: 325
#
# ---------------------------------------------------------------------------------------------
# 185 file(s) completed. Lines added: 5987
#
# ---------------------------------------------------------------------------------------------
#
# 186 file(s) completed. Lines added: 703
#
# ---------------------------------------------------------------------------------------------
#
# 187 file(s) completed. Lines added: 447
#
# ---------------------------------------------------------------------------------------------
#
# 188 file(s) completed. Lines added: 734
#
# ---------------------------------------------------------------------------------------------
#
# 189 file(s) completed. Lines added: 3263
#
# ---------------------------------------------------------------------------------------------
#
# 190 file(s) completed. Lines added: 593
#
# ---------------------------------------------------------------------------------------------
#
# 191 file(s) completed. Lines added: 2934
#
# ---------------------------------------------------------------------------------------------
#
# 192 file(s) completed. Lines added: 1060
#
# ---------------------------------------------------------------------------------------------
#
# 193 file(s) completed. Lines added: 1211
#
# ---------------------------------------------------------------------------------------------
#
# 194 file(s) completed. Lines added: 953
#
# ---------------------------------------------------------------------------------------------
#
# 195 file(s) completed. Lines added: 24125
#
# ---------------------------------------------------------------------------------------------
#
# 196 file(s) completed. Lines added: 904
#
# ---------------------------------------------------------------------------------------------
#
# 197 file(s) completed. Lines added: 767
#
# ---------------------------------------------------------------------------------------------
#
# 198 file(s) completed. Lines added: 14570
#
# ---------------------------------------------------------------------------------------------
#
# 199 file(s) completed. Lines added: 800
#
# ---------------------------------------------------------------------------------------------
#
# 200 file(s) completed. Lines added: 674
#
# ---------------------------------------------------------------------------------------------
#
# 201 file(s) completed. Lines added: 228
#
# ---------------------------------------------------------------------------------------------
#
# 202 file(s) completed. Lines added: 218
#
# ---------------------------------------------------------------------------------------------
#
# 203 file(s) completed. Lines added: 336
#
# ---------------------------------------------------------------------------------------------
#
# 204 file(s) completed. Lines added: 711
#
# ---------------------------------------------------------------------------------------------
#
# 205 file(s) completed. Lines added: 183
#
# ---------------------------------------------------------------------------------------------
#
# 206 file(s) completed. Lines added: 4945
#
# ---------------------------------------------------------------------------------------------
#
# 207 file(s) completed. Lines added: 833
#
# ---------------------------------------------------------------------------------------------
#
# 208 file(s) completed. Lines added: 2302
#
# ---------------------------------------------------------------------------------------------
#
# 209 file(s) completed. Lines added: 1468
#
# ---------------------------------------------------------------------------------------------
#
# 210 file(s) completed. Lines added: 468
#
# ---------------------------------------------------------------------------------------------
#
# 211 file(s) completed. Lines added: 695
#
# ---------------------------------------------------------------------------------------------
#
# 212 file(s) completed. Lines added: 6201
#
# ---------------------------------------------------------------------------------------------
#
# 213 file(s) completed. Lines added: 11134
#
# ---------------------------------------------------------------------------------------------
#
# 214 file(s) completed. Lines added: 1629
#
# ---------------------------------------------------------------------------------------------
#
# 215 file(s) completed. Lines added: 3669
#
# ---------------------------------------------------------------------------------------------
#
# 216 file(s) completed. Lines added: 668
#
# ---------------------------------------------------------------------------------------------
#
# 217 file(s) completed. Lines added: 672
#
# ---------------------------------------------------------------------------------------------
#
# 218 file(s) completed. Lines added: 648
#
# ---------------------------------------------------------------------------------------------
#
# 219 file(s) completed. Lines added: 437
#
# ---------------------------------------------------------------------------------------------
#
# 220 file(s) completed. Lines added: 731
#
# ---------------------------------------------------------------------------------------------
#
# 221 file(s) completed. Lines added: 1093
#
# ---------------------------------------------------------------------------------------------
#
# 222 file(s) completed. Lines added: 1316
#
# ---------------------------------------------------------------------------------------------
#
# 223 file(s) completed. Lines added: 374
#
# ---------------------------------------------------------------------------------------------
#
# 224 file(s) completed. Lines added: 1062
#
# ---------------------------------------------------------------------------------------------
#
# 225 file(s) completed. Lines added: 273
#
# ---------------------------------------------------------------------------------------------
#
# 226 file(s) completed. Lines added: 1501
#
# ---------------------------------------------------------------------------------------------
#
# 227 file(s) completed. Lines added: 331
#
# ---------------------------------------------------------------------------------------------
#
# 228 file(s) completed. Lines added: 386
#
# ---------------------------------------------------------------------------------------------
#
# 229 file(s) completed. Lines added: 340
#
# ---------------------------------------------------------------------------------------------
#
# 230 file(s) completed. Lines added: 641
#
# ---------------------------------------------------------------------------------------------
#
# 231 file(s) completed. Lines added: 323
#
# ---------------------------------------------------------------------------------------------
#
# 232 file(s) completed. Lines added: 1151
#
# ---------------------------------------------------------------------------------------------
#
# 233 file(s) completed. Lines added: 551
#
# ---------------------------------------------------------------------------------------------
#
# 234 file(s) completed. Lines added: 1039
#
# ---------------------------------------------------------------------------------------------
#
# 235 file(s) completed. Lines added: 737
#
# ---------------------------------------------------------------------------------------------
#
# 236 file(s) completed. Lines added: 552
#
# ---------------------------------------------------------------------------------------------
#
# 237 file(s) completed. Lines added: 199
#
# ---------------------------------------------------------------------------------------------
#
# 238 file(s) completed. Lines added: 2088
#
# ---------------------------------------------------------------------------------------------
#
# 239 file(s) completed. Lines added: 438
#
# ---------------------------------------------------------------------------------------------
#
# 240 file(s) completed. Lines added: 281
#
# ---------------------------------------------------------------------------------------------
#
# 241 file(s) completed. Lines added: 2058
#
# ---------------------------------------------------------------------------------------------
#
# 242 file(s) completed. Lines added: 501
#
# ---------------------------------------------------------------------------------------------
#
# 243 file(s) completed. Lines added: 5492
#
# ---------------------------------------------------------------------------------------------
#
# 244 file(s) completed. Lines added: 440
#
# ---------------------------------------------------------------------------------------------
#
# 245 file(s) completed. Lines added: 576
#
# ---------------------------------------------------------------------------------------------
# 246 file(s) completed. Lines added: 7637
#
# ---------------------------------------------------------------------------------------------
#
# 247 file(s) completed. Lines added: 559
#
# ---------------------------------------------------------------------------------------------
#
# 248 file(s) completed. Lines added: 88
#
# ---------------------------------------------------------------------------------------------
#
# 249 file(s) completed. Lines added: 570
#
# ---------------------------------------------------------------------------------------------
#
# 250 file(s) completed. Lines added: 2320
#
# ---------------------------------------------------------------------------------------------
#
# 251 file(s) completed. Lines added: 490
#
# ---------------------------------------------------------------------------------------------
#
# 252 file(s) completed. Lines added: 1468
#
# ---------------------------------------------------------------------------------------------
#
# 253 file(s) completed. Lines added: 313
#
# ---------------------------------------------------------------------------------------------
#
# 254 file(s) completed. Lines added: 214
#
# ---------------------------------------------------------------------------------------------
#
# 255 file(s) completed. Lines added: 539
#
# ---------------------------------------------------------------------------------------------
#
# 256 file(s) completed. Lines added: 5364
#
# ---------------------------------------------------------------------------------------------
#
# 257 file(s) completed. Lines added: 530
#
# ---------------------------------------------------------------------------------------------
#
# 258 file(s) completed. Lines added: 11
#
# ---------------------------------------------------------------------------------------------
#
# 259 file(s) completed. Lines added: 985
#
# ---------------------------------------------------------------------------------------------
#
# 260 file(s) completed. Lines added: 1037
#
# ---------------------------------------------------------------------------------------------
#
# 261 file(s) completed. Lines added: 3466
#
# ---------------------------------------------------------------------------------------------
#
# 262 file(s) completed. Lines added: 1605
#
# ---------------------------------------------------------------------------------------------
#
# 263 file(s) completed. Lines added: 477
#
# ---------------------------------------------------------------------------------------------
#
# 264 file(s) completed. Lines added: 362
#
# ---------------------------------------------------------------------------------------------
#
# 265 file(s) completed. Lines added: 216
#
# ---------------------------------------------------------------------------------------------
#
# 266 file(s) completed. Lines added: 393
#
# ---------------------------------------------------------------------------------------------
#
# 267 file(s) completed. Lines added: 1071
#
# ---------------------------------------------------------------------------------------------
#
# 268 file(s) completed. Lines added: 542
#
# ---------------------------------------------------------------------------------------------
#
# 269 file(s) completed. Lines added: 469
#
# ---------------------------------------------------------------------------------------------
#
# 270 file(s) completed. Lines added: 31
#
# ---------------------------------------------------------------------------------------------
#
# 271 file(s) completed. Lines added: 330
#
# ---------------------------------------------------------------------------------------------
#
# 272 file(s) completed. Lines added: 1992
#
# ---------------------------------------------------------------------------------------------
#
# 273 file(s) completed. Lines added: 970
#
# ---------------------------------------------------------------------------------------------
#
# 274 file(s) completed. Lines added: 3976
#
# ---------------------------------------------------------------------------------------------
#
# 275 file(s) completed. Lines added: 393
#
# ---------------------------------------------------------------------------------------------
#
# 276 file(s) completed. Lines added: 77
#
# ---------------------------------------------------------------------------------------------
#
# 277 file(s) completed. Lines added: 4148
#
# ---------------------------------------------------------------------------------------------
#
# 278 file(s) completed. Lines added: 267
#
# ---------------------------------------------------------------------------------------------
#
# 279 file(s) completed. Lines added: 822
#
# ---------------------------------------------------------------------------------------------
#
# 280 file(s) completed. Lines added: 59
#
# ---------------------------------------------------------------------------------------------
#
# 281 file(s) completed. Lines added: 520
#
# ---------------------------------------------------------------------------------------------
#
# 282 file(s) completed. Lines added: 271
#
# ---------------------------------------------------------------------------------------------
#
# 283 file(s) completed. Lines added: 368
#
# ---------------------------------------------------------------------------------------------
#
# 284 file(s) completed. Lines added: 737
#
# ---------------------------------------------------------------------------------------------
#
# 285 file(s) completed. Lines added: 905
#
# ---------------------------------------------------------------------------------------------
#
# 286 file(s) completed. Lines added: 1362
#
# ---------------------------------------------------------------------------------------------
#
# 287 file(s) completed. Lines added: 610
#
# ---------------------------------------------------------------------------------------------
#
# 288 file(s) completed. Lines added: 259
#
# ---------------------------------------------------------------------------------------------
#
# 289 file(s) completed. Lines added: 222
#
# ---------------------------------------------------------------------------------------------
#
# 290 file(s) completed. Lines added: 620
#
# ---------------------------------------------------------------------------------------------
#
# 291 file(s) completed. Lines added: 352
#
# ---------------------------------------------------------------------------------------------
#
# 292 file(s) completed. Lines added: 333
#
# ---------------------------------------------------------------------------------------------
#
# 293 file(s) completed. Lines added: 243
#
# ---------------------------------------------------------------------------------------------
#
# 294 file(s) completed. Lines added: 534
#
# ---------------------------------------------------------------------------------------------
#
# 295 file(s) completed. Lines added: 222
#
# ---------------------------------------------------------------------------------------------
#
# 296 file(s) completed. Lines added: 718
#
# ---------------------------------------------------------------------------------------------
#
# 297 file(s) completed. Lines added: 442
#
# ---------------------------------------------------------------------------------------------
#
# 298 file(s) completed. Lines added: 269
#
# ---------------------------------------------------------------------------------------------
#
# 299 file(s) completed. Lines added: 74
#
# ---------------------------------------------------------------------------------------------
#
# 300 file(s) completed. Lines added: 1099
#
# ---------------------------------------------------------------------------------------------
#
# 301 file(s) completed. Lines added: 1597
#
# ---------------------------------------------------------------------------------------------
#
# 302 file(s) completed. Lines added: 811
#
# ---------------------------------------------------------------------------------------------
#
# 303 file(s) completed. Lines added: 205
#
# ---------------------------------------------------------------------------------------------
#
# 304 file(s) completed. Lines added: 5307
#
# ---------------------------------------------------------------------------------------------
#
# 305 file(s) completed. Lines added: 2592
#
# ---------------------------------------------------------------------------------------------
#
# 306 file(s) completed. Lines added: 915
#
# ---------------------------------------------------------------------------------------------
#
# 307 file(s) completed. Lines added: 657
#
# ---------------------------------------------------------------------------------------------
# 308 file(s) completed. Lines added: 606
#
# ---------------------------------------------------------------------------------------------
#
# 309 file(s) completed. Lines added: 2415
#
# ---------------------------------------------------------------------------------------------
#
# 310 file(s) completed. Lines added: 6175
#
# ---------------------------------------------------------------------------------------------
#
# 311 file(s) completed. Lines added: 812
#
# ---------------------------------------------------------------------------------------------
#
# 312 file(s) completed. Lines added: 89
#
# ---------------------------------------------------------------------------------------------
#
# 313 file(s) completed. Lines added: 4597
#
# ---------------------------------------------------------------------------------------------
#
# 314 file(s) completed. Lines added: 873
#
# ---------------------------------------------------------------------------------------------
#
# 315 file(s) completed. Lines added: 8183
#
# ---------------------------------------------------------------------------------------------
#
# 316 file(s) completed. Lines added: 546
#
# ---------------------------------------------------------------------------------------------
#
# 317 file(s) completed. Lines added: 10951
#
# ---------------------------------------------------------------------------------------------
#
# 318 file(s) completed. Lines added: 823
#
# ---------------------------------------------------------------------------------------------
#
# 319 file(s) completed. Lines added: 6199
#
# ---------------------------------------------------------------------------------------------
#
# 320 file(s) completed. Lines added: 1347
#
# ---------------------------------------------------------------------------------------------
#
# 321 file(s) completed. Lines added: 240
#
# ---------------------------------------------------------------------------------------------
#
# 322 file(s) completed. Lines added: 732
#
# ---------------------------------------------------------------------------------------------
#
# 323 file(s) completed. Lines added: 2257
#
# ---------------------------------------------------------------------------------------------
#
# 324 file(s) completed. Lines added: 128
#
# ---------------------------------------------------------------------------------------------
#
# 325 file(s) completed. Lines added: 194
#
# ---------------------------------------------------------------------------------------------
#
# 326 file(s) completed. Lines added: 395
#
# ---------------------------------------------------------------------------------------------
#
# 327 file(s) completed. Lines added: 826
#
# ---------------------------------------------------------------------------------------------
#
# 328 file(s) completed. Lines added: 510
#
# ---------------------------------------------------------------------------------------------
#
# 329 file(s) completed. Lines added: 729
#
# ---------------------------------------------------------------------------------------------
#
# 330 file(s) completed. Lines added: 383
#
# ---------------------------------------------------------------------------------------------
#
# 331 file(s) completed. Lines added: 546
#
# ---------------------------------------------------------------------------------------------
#
# 332 file(s) completed. Lines added: 2567
#
# ---------------------------------------------------------------------------------------------
#
# 333 file(s) completed. Lines added: 152
#
# ---------------------------------------------------------------------------------------------
#
# 334 file(s) completed. Lines added: 7770
#
# ---------------------------------------------------------------------------------------------
#
# 335 file(s) completed. Lines added: 316
#
# ---------------------------------------------------------------------------------------------
#
# 336 file(s) completed. Lines added: 257
#
# ---------------------------------------------------------------------------------------------
#
# 337 file(s) completed. Lines added: 1312
#
# ---------------------------------------------------------------------------------------------
#
# 338 file(s) completed. Lines added: 395
#
# ---------------------------------------------------------------------------------------------
#
# 339 file(s) completed. Lines added: 1366
#
# ---------------------------------------------------------------------------------------------
#
# 340 file(s) completed. Lines added: 2930
#
# ---------------------------------------------------------------------------------------------
#
# 341 file(s) completed. Lines added: 1175
#
# ---------------------------------------------------------------------------------------------
#
# 342 file(s) completed. Lines added: 3013
#
# ---------------------------------------------------------------------------------------------
#
# 343 file(s) completed. Lines added: 982
#
# ---------------------------------------------------------------------------------------------
#
# 344 file(s) completed. Lines added: 5724
#
# ---------------------------------------------------------------------------------------------
#
# 345 file(s) completed. Lines added: 896
#
# ---------------------------------------------------------------------------------------------
#
# 346 file(s) completed. Lines added: 9447
#
# ---------------------------------------------------------------------------------------------
#
# 347 file(s) completed. Lines added: 1980
#
# ---------------------------------------------------------------------------------------------
#
# 348 file(s) completed. Lines added: 238
#
# ---------------------------------------------------------------------------------------------
#
# 349 file(s) completed. Lines added: 592
#
# ---------------------------------------------------------------------------------------------
#
# 350 file(s) completed. Lines added: 3407
#
# ---------------------------------------------------------------------------------------------
#
# 351 file(s) completed. Lines added: 1859
#
# ---------------------------------------------------------------------------------------------
#
# 352 file(s) completed. Lines added: 1813
#
# ---------------------------------------------------------------------------------------------
#
# 353 file(s) completed. Lines added: 461
#
# ...
#
# ---------------------------------------------------------------------------------------------
#
# 253 file(s) completed. Lines added: 21
#
# ---------------------------------------------------------------------------------------------
#
# 254 file(s) completed. Lines added: 49
#
# ---------------------------------------------------------------------------------------------
#
# 255 file(s) completed. Lines added: 28
#
# ---------------------------------------------------------------------------------------------
#
# 256 file(s) completed. Lines added: 38
#
# ---------------------------------------------------------------------------------------------
#
# 257 file(s) completed. Lines added: 32
#
# ---------------------------------------------------------------------------------------------
#
# 258 file(s) completed. Lines added: 46
#
# ---------------------------------------------------------------------------------------------
#
# 259 file(s) completed. Lines added: 20
#
# ---------------------------------------------------------------------------------------------
#
# 260 file(s) completed. Lines added: 16
#
# ---------------------------------------------------------------------------------------------
#
# 261 file(s) completed. Lines added: 14
#
# ---------------------------------------------------------------------------------------------
#
# 262 file(s) completed. Lines added: 34
#
# ---------------------------------------------------------------------------------------------
#
# 263 file(s) completed. Lines added: 4
#
# ---------------------------------------------------------------------------------------------
#
# 264 file(s) completed. Lines added: 3
#
# ---------------------------------------------------------------------------------------------
#
# 265 file(s) completed. Lines added: 0
#
# ---------------------------------------------------------------------------------------------
#
# 266 file(s) completed. Lines added: 1
#
# ---------------------------------------------------------------------------------------------
#
# 267 file(s) completed. Lines added: 0
#
# ---------------------------------------------------------------------------------------------
#
# 268 file(s) completed. Lines added: 1
#
# ---------------------------------------------------------------------------------------------
#
# 269 file(s) completed. Lines added: 3
#
# ---------------------------------------------------------------------------------------------
#
# 270 file(s) completed. Lines added: 3
#
# ---------------------------------------------------------------------------------------------
#
# 271 file(s) completed. Lines added: 1
#
# ---------------------------------------------------------------------------------------------
#
# 272 file(s) completed. Lines added: 4
#
# ---------------------------------------------------------------------------------------------
#
# 273 file(s) completed. Lines added: 4
#
# ---------------------------------------------------------------------------------------------
#
# 274 file(s) completed. Lines added: 0
#
# ---------------------------------------------------------------------------------------------
#
# 275 file(s) completed. Lines added: 4
#
# ---------------------------------------------------------------------------------------------
#
# 276 file(s) completed. Lines added: 0
#
# ---------------------------------------------------------------------------------------------
#
# 277 file(s) completed. Lines added: 8
#
# ---------------------------------------------------------------------------------------------
#
# 278 file(s) completed. Lines added: 5
#
# ---------------------------------------------------------------------------------------------
#
# 279 file(s) completed. Lines added: 1
#
# ---------------------------------------------------------------------------------------------
#
# 280 file(s) completed. Lines added: 4
#
# ---------------------------------------------------------------------------------------------
#
# 281 file(s) completed. Lines added: 0
#
# ---------------------------------------------------------------------------------------------
#
# 282 file(s) completed. Lines added: 5
#
# ---------------------------------------------------------------------------------------------
#
# 283 file(s) completed. Lines added: 6
#
# ---------------------------------------------------------------------------------------------
#
# 284 file(s) completed. Lines added: 1
#
# ---------------------------------------------------------------------------------------------
#
# 285 file(s) completed. Lines added: 0
#
# ---------------------------------------------------------------------------------------------
#
# 286 file(s) completed. Lines added: 7
#
# ---------------------------------------------------------------------------------------------
#
# 287 file(s) completed. Lines added: 4
#
# ---------------------------------------------------------------------------------------------
#
# 288 file(s) completed. Lines added: 1
#
# ---------------------------------------------------------------------------------------------
#
# 289 file(s) completed. Lines added: 1
#
# ---------------------------------------------------------------------------------------------
#
# 290 file(s) completed. Lines added: 2
#
# ---------------------------------------------------------------------------------------------
#
# 291 file(s) completed. Lines added: 2
#
# ---------------------------------------------------------------------------------------------
#
# 292 file(s) completed. Lines added: 4
#
# ---------------------------------------------------------------------------------------------
#
# 293 file(s) completed. Lines added: 37
#
# ---------------------------------------------------------------------------------------------
#
# 294 file(s) completed. Lines added: 24
#
# ---------------------------------------------------------------------------------------------
#
# 295 file(s) completed. Lines added: 6
#
# ---------------------------------------------------------------------------------------------
#
# 296 file(s) completed. Lines added: 4
#
# ---------------------------------------------------------------------------------------------
#
# 297 file(s) completed. Lines added: 29
#
# ---------------------------------------------------------------------------------------------
#
# 298 file(s) completed. Lines added: 4
#
# ---------------------------------------------------------------------------------------------
#
# 299 file(s) completed. Lines added: 10
#
# ---------------------------------------------------------------------------------------------
#
# 300 file(s) completed. Lines added: 14
#
# ---------------------------------------------------------------------------------------------
#
# 301 file(s) completed. Lines added: 31
#
# ---------------------------------------------------------------------------------------------
#
# 302 file(s) completed. Lines added: 9
#
# ---------------------------------------------------------------------------------------------
#
# 303 file(s) completed. Lines added: 2
#
# ---------------------------------------------------------------------------------------------
#
# 304 file(s) completed. Lines added: 3
#
# ---------------------------------------------------------------------------------------------
#
# 305 file(s) completed. Lines added: 22
#
# ---------------------------------------------------------------------------------------------
#
# 306 file(s) completed. Lines added: 10
#
# ---------------------------------------------------------------------------------------------
#
# 307 file(s) completed. Lines added: 23
#
# ---------------------------------------------------------------------------------------------
#
# 308 file(s) completed. Lines added: 25
#
# ---------------------------------------------------------------------------------------------
#
# 309 file(s) completed. Lines added: 1
#
# ---------------------------------------------------------------------------------------------
#
# 310 file(s) completed. Lines added: 5
#
# ---------------------------------------------------------------------------------------------
#
# 311 file(s) completed. Lines added: 25
#
# ---------------------------------------------------------------------------------------------
#
# 312 file(s) completed. Lines added: 8
#
# ---------------------------------------------------------------------------------------------
#
# 313 file(s) completed. Lines added: 0
#
# ---------------------------------------------------------------------------------------------
#
# 314 file(s) completed. Lines added: 2
#
# ---------------------------------------------------------------------------------------------
#
# 315 file(s) completed. Lines added: 0
#
# ---------------------------------------------------------------------------------------------
#
# 316 file(s) completed. Lines added: 0
#
# ---------------------------------------------------------------------------------------------
#
# 317 file(s) completed. Lines added: 8
#
# ---------------------------------------------------------------------------------------------
#
# 318 file(s) completed. Lines added: 12
#
# ---------------------------------------------------------------------------------------------
#
# 319 file(s) completed. Lines added: 16
#
# ---------------------------------------------------------------------------------------------
#
# 320 file(s) completed. Lines added: 1
#
# ---------------------------------------------------------------------------------------------
#
# 321 file(s) completed. Lines added: 35
#
# ---------------------------------------------------------------------------------------------
#
# 322 file(s) completed. Lines added: 11
#
# ---------------------------------------------------------------------------------------------
#
# 323 file(s) completed. Lines added: 6
#
# ---------------------------------------------------------------------------------------------
#
# 324 file(s) completed. Lines added: 1
#
# ---------------------------------------------------------------------------------------------
#
# 325 file(s) completed. Lines added: 64
#
# ---------------------------------------------------------------------------------------------
#
# 326 file(s) completed. Lines added: 47
#
# ---------------------------------------------------------------------------------------------
#
# 327 file(s) completed. Lines added: 58
#
# ---------------------------------------------------------------------------------------------
# 328 file(s) completed. Lines added: 39
#
# ---------------------------------------------------------------------------------------------
#
# 329 file(s) completed. Lines added: 26
#
# ---------------------------------------------------------------------------------------------
#
# 330 file(s) completed. Lines added: 57
#
# ---------------------------------------------------------------------------------------------
#
# 331 file(s) completed. Lines added: 64
#
# ---------------------------------------------------------------------------------------------
#
# 332 file(s) completed. Lines added: 12
#
# ---------------------------------------------------------------------------------------------
#
# 333 file(s) completed. Lines added: 83
#
# ---------------------------------------------------------------------------------------------
#
# 334 file(s) completed. Lines added: 58
#
# ---------------------------------------------------------------------------------------------
#
# 335 file(s) completed. Lines added: 65
#
# ---------------------------------------------------------------------------------------------
#
# 336 file(s) completed. Lines added: 0
#
# ---------------------------------------------------------------------------------------------
#
# 337 file(s) completed. Lines added: 0
#
# ---------------------------------------------------------------------------------------------
#
# 338 file(s) completed. Lines added: 53
#
# ---------------------------------------------------------------------------------------------
#
# 339 file(s) completed. Lines added: 20
#
# ---------------------------------------------------------------------------------------------
#
# 340 file(s) completed. Lines added: 114
#
# ---------------------------------------------------------------------------------------------
#
# 341 file(s) completed. Lines added: 132
#
# ---------------------------------------------------------------------------------------------
#
# 342 file(s) completed. Lines added: 105
#
# ---------------------------------------------------------------------------------------------
#
# 343 file(s) completed. Lines added: 18
#
# ---------------------------------------------------------------------------------------------
#
# 344 file(s) completed. Lines added: 23
#
# ---------------------------------------------------------------------------------------------
#
# 345 file(s) completed. Lines added: 7
#
# ---------------------------------------------------------------------------------------------
#
# 346 file(s) completed. Lines added: 87
#
# ---------------------------------------------------------------------------------------------
#
# 347 file(s) completed. Lines added: 78
#
# ---------------------------------------------------------------------------------------------
#
# 348 file(s) completed. Lines added: 95
#
# ---------------------------------------------------------------------------------------------
#
# 349 file(s) completed. Lines added: 47
#
# ---------------------------------------------------------------------------------------------
#
# 350 file(s) completed. Lines added: 24
#
# ---------------------------------------------------------------------------------------------
#
# 351 file(s) completed. Lines added: 99
#
# ---------------------------------------------------------------------------------------------
#
# 352 file(s) completed. Lines added: 137
#
# ---------------------------------------------------------------------------------------------
#
# 353 file(s) completed. Lines added: 133
#
# ---------------------------------------------------------------------------------------------
#
# 354 file(s) completed. Lines added: 101
#
# ---------------------------------------------------------------------------------------------
#
# 355 file(s) completed. Lines added: 32
#
# ---------------------------------------------------------------------------------------------
#
# 356 file(s) completed. Lines added: 83
#
# ---------------------------------------------------------------------------------------------
#
# 357 file(s) completed. Lines added: 21
#
# ---------------------------------------------------------------------------------------------
#
# 358 file(s) completed. Lines added: 125
#
# ---------------------------------------------------------------------------------------------
#
# 359 file(s) completed. Lines added: 134
#
# ---------------------------------------------------------------------------------------------
#
# 360 file(s) completed. Lines added: 68
#
# ---------------------------------------------------------------------------------------------
#
# 361 file(s) completed. Lines added: 96
#
# ---------------------------------------------------------------------------------------------
#
# 362 file(s) completed. Lines added: 242
#
# ---------------------------------------------------------------------------------------------
#
# 363 file(s) completed. Lines added: 72
#
# ---------------------------------------------------------------------------------------------
#
# 364 file(s) completed. Lines added: 63
#
# ---------------------------------------------------------------------------------------------
#
# 365 file(s) completed. Lines added: 75
#
# ---------------------------------------------------------------------------------------------
#
# 366 file(s) completed. Lines added: 147
#
# ---------------------------------------------------------------------------------------------
#
# 367 file(s) completed. Lines added: 82
#
# ---------------------------------------------------------------------------------------------
#
# 368 file(s) completed. Lines added: 25
#
# ---------------------------------------------------------------------------------------------
#
# 369 file(s) completed. Lines added: 41
#
# ---------------------------------------------------------------------------------------------
#
# 370 file(s) completed. Lines added: 105
#
# ---------------------------------------------------------------------------------------------

# %%
dataProcessor.line_count
# Out:
# 4763437

# %%
dataProcessor.line_per_docsite
# Out:
# {'spec': 16879291,
#  'eventhelix': 595,
#  'techplayon': 5220,
#  'telecompedia': 2173,
#  'howltestuffworks': 4213,
#  'rfwireless-world': 610,
#  '3glteinfo': 790,
#  'sharetechnote': 0,
#  'prodevelopertutorial': 3178,
#  '4g5gworld': 80,
#  'artizanetworks': 383,
#  'info-nrlte': 508,
#  'resurchify': 138}

# %%
dataProcessor.word_per_docsite
# Out:
# {'spec': 134251922,
#  'eventhelix': 6691,
#  'techplayon': 89035,
#  'telecompedia': 24997,
#  'howltestuffworks': 65520,
#  'rfwireless-world': 8032,
#  '3glteinfo': 9651,
#  'sharetechnote': 0,
#  'prodevelopertutorial': 31708,
#  '4g5gworld': 1069,
#  'artizanetworks': 5182,
#  'info-nrlte': 7431,
#  'resurchify': 1815}

# %%
sum(dataProcessor.word_per_docsite.values())
# Out:
# 134503053

# %%
dataProcessor.line_per_spec
# Out:
# {576: 15,
#  464: 6,
#  350: 10,
#  1576: 3,
#  402: 15,
#  186: 22,
#  244: 8,
#  7621: 1,
#  2726: 3,
#  1065: 7,
#  7559: 1,
#  2429: 4,
#  705: 6,
#  393: 12,
#  379: 9,
#  1699: 4,
#  797: 8,
#  438: 20,
#  332: 12,
#  334: 16,
#  834: 7,
#  2127: 1,
#  2024: 1,
#  748: 6,
#  1016: 2,
#  649: 22,
#  178: 16,
#  807: 7,
#  708: 16,
#  897: 6,
#  487: 8,
#  913: 4,
#  1142: 10,
#  1072: 3,
#  2542: 3,
#  569: 11,
#  12683: 1,
#  4385: 1,
#  3763: 2,
#  351: 16,
#  676: 7,
#  6545: 1,
#  2940: 1,
#  875: 2,
#  1139: 2,
#  993: 3,
#  573: 6,
#  9593: 1,
#  1523: 1,
#  352: 18,
#  760: 3,
#  935: 2,
#  4628: 2,
#  1816: 3,
#  1320: 10,
#  6778: 1,
#  1204: 2,
#  236: 11,
#  232: 16,
#  540: 12,
#  687: 7,
#  476: 4,
#  634: 5,
#  299: 18,
#  110: 17,
#  1528: 4,
#  520: 10,
#  180: 15,
#  176: 10,
#  473: 11,
#  212: 16,
#  868: 6,
#  3000: 2,
#  3785: 1,
#  333: 15,
#  1713: 3,
#  2838: 3,
#  3311: 3,
#  1395: 3,
#  137: 16,
#  373: 12,
#  2618: 4,
#  1256: 5,
#  1053: 5,
#  1300: 2,
#  551: 15,
#  5948: 1,
#  1598: 5,
#  1810: 1,
#  502: 16,
#  1337: 2,
#  714: 6,
#  12190: 1,
#  2509: 2,
#  1070: 4,
#  267: 20,
#  3614: 2,
#  3616: 1,
#  2308: 1,
#  2763: 2,
#  1723: 1,
#  667: 14,
#  1032: 2,
#  4547: 1,
#  1515: 3,
#  664: 7,
#  196: 17,
#  306: 16,
#  1342: 2,
#  1347: 4,
#  1873: 2,
#  1808: 1,
#  204: 19,
#  2307: 1,
#  1197: 2,
#  2781: 2,
#  1107: 1,
#  997: 7,
#  1900: 1,
#  2040: 1,
#  2707: 1,
#  3875: 1,
#  4047: 6,
#  552: 8,
#  1712: 7,
#  665: 9,
#  928: 7,
#  4552: 2,
#  912: 5,
#  539: 19,
#  1887: 8,
#  191: 7,
#  529: 6,
#  374: 22,
#  887: 10,
#  432: 8,
#  3416: 1,
#  3709: 3,
#  1454: 5,
#  1968: 2,
#  1080: 11,
#  1752: 5,
#  719: 6,
#  524: 8,
#  2271: 1,
#  1077: 2,
#  139: 10,
#  1057: 6,
#  1166: 2,
#  2843: 3,
#  2744: 1,
#  1595: 1,
#  638: 9,
#  1309: 1,
#  565: 9,
#  1518: 2,
#  404: 16,
#  230: 16,
#  2684: 1,
#  1747: 2,
#  1343: 1,
#  690: 3,
#  679: 5,
#  4041: 2,
#  2091: 2,
#  4135: 2,
#  3982: 1,
#  639: 13,
#  2643: 1,
#  1357: 1,
#  1820: 2,
#  1819: 3,
#  592: 5,
#  2699: 4,
#  2270: 3,
#  3079: 2,
#  1409: 4,
#  763: 7,
#  325: 10,
#  5987: 1,
#  703: 5,
#  447: 9,
#  734: 9,
#  3263: 2,
#  593: 9,
#  2934: 1,
#  1060: 10,
#  1211: 5,
#  953: 3,
#  24125: 1,
#  904: 8,
#  767: 13,
#  14570: 1,
#  800: 10,
#  674: 6,
#  228: 19,
#  218: 21,
#  336: 10,
#  711: 6,
#  183: 22,
#  4945: 1,
#  833: 4,
#  2302: 2,
#  1468: 8,
#  468: 10,
#  695: 8,
#  6201: 1,
#  11134: 6,
#  1629: 2,
#  3669: 6,
#  668: 10,
#  672: 7,
#  648: 11,
#  437: 12,
#  731: 6,
#  1093: 4,
#  1316: 3,
#  1062: 7,
#  273: 20,
#  1501: 4,
#  331: 13,
#  386: 14,
#  340: 12,
#  641: 13,
#  323: 12,
#  1151: 6,
#  1039: 6,
#  737: 9,
#  199: 20,
#  2088: 3,
#  281: 15,
#  2058: 5,
#  501: 12,
#  5492: 1,
#  440: 14,
#  7637: 1,
#  559: 13,
#  88: 11,
#  570: 8,
#  2320: 4,
#  490: 4,
#  313: 14,
#  214: 17,
#  5364: 1,
#  530: 19,
#  11: 11,
#  985: 6,
#  1037: 8,
#  3466: 1,
#  1605: 3,
#  477: 7,
#  362: 16,
#  216: 22,
#  1071: 7,
#  542: 11,
#  469: 9,
#  31: 1,
#  330: 13,
#  1992: 1,
#  970: 3,
#  3976: 1,
#  77: 19,
#  4148: 4,
#  822: 8,
#  59: 14,
#  271: 10,
#  368: 16,
#  905: 7,
#  1362: 3,
#  610: 10,
#  259: 22,
#  222: 22,
#  620: 10,
#  243: 15,
#  534: 18,
#  718: 13,
#  442: 14,
#  269: 13,
#  74: 9,
#  1099: 6,
#  1597: 6,
#  811: 7,
#  205: 15,
#  5307: 1,
#  2592: 1,
#  915: 7,
#  657: 10,
#  606: 7,
#  2415: 1,
#  6175: 2,
#  812: 11,
#  89: 20,
#  4597: 2,
#  873: 2,
#  8183: 1,
#  546: 7,
#  10951: 4,
#  823: 5,
#  6199: 2,
#  240: 14,
#  732: 9,
#  2257: 5,
#  128: 20,
#  194: 9,
#  395: 12,
#  826: 5,
#  510: 8,
#  729: 10,
#  383: 10,
#  2567: 1,
#  152: 10,
#  7770: 1,
#  316: 8,
#  257: 14,
#  1312: 2,
#  1366: 2,
#  2930: 2,
#  1175: 4,
#  3013: 1,
#  982: 10,
#  5724: 1,
#  896: 5,
#  9447: 1,
#  1980: 4,
#  238: 27,
#  3407: 3,
#  1859: 1,
#  1813: 3,
#  461: 15,
#  1040: 3,
#  630: 3,
#  112: 19,
#  2975: 1,
#  2245: 1,
#  2619: 4,
#  11417: 1,
#  5491: 1,
#  3906: 1,
#  805: 8,
#  1840: 2,
#  4003: 1,
#  1101: 3,
#  507: 6,
#  713: 4,
#  9083: 1,
#  6606: 1,
#  609: 2,
#  4638: 1,
#  801: 5,
#  1750: 6,
#  2627: 2,
#  370: 17,
#  1910: 4,
#  532: 11,
#  5705: 2,
#  2143: 1,
#  555: 10,
#  1710: 6,
#  983: 10,
#  778: 4,
#  3474: 1,
#  3176: 2,
#  396: 16,
#  514: 9,
#  3804: 6,
#  726: 6,
#  1455: 6,
#  945: 4,
#  2591: 1,
#  783: 2,
#  470: 9,
#  111: 15,
#  479: 16,
#  1076: 3,
#  691: 3,
#  3218: 1,
#  2392: 1,
#  109: 27,
#  278: 9,
#  1888: 1,
#  589: 9,
#  188: 9,
#  268: 18,
#  161: 10,
#  1464: 1,
#  1640: 2,
#  127: 11,
#  723: 8,
#  365: 9,
#  296: 10,
#  197: 15,
#  1431: 2,
#  1440: 2,
#  3111: 1,
#  105: 15,
#  974: 3,
#  788: 4,
#  829: 9,
#  135: 20,
#  1201: 4,
#  234: 20,
#  154: 9,
#  170: 12,
#  142: 13,
#  3337: 1,
#  998: 2,
#  321: 16,
#  583: 4,
#  650: 8,
#  965: 5,
#  385: 14,
#  300: 11,
#  697: 10,
#  2793: 1,
#  389: 13,
#  2083: 1,
#  2278: 2,
#  311: 9,
#  317: 10,
#  613: 7,
#  4025: 2,
#  448: 18,
#  126: 14,
#  585: 5,
#  653: 7,
#  950: 12,
#  184: 19,
#  293: 7,
#  781: 6,
#  478: 10,
#  1264: 4,
#  793: 4,
#  1574: 3,
#  562: 11,
#  115: 23,
#  2000: 1,
#  721: 6,
#  406: 7,
#  757: 5,
#  2118: 3,
#  1406: 4,
#  70: 5,
#  533: 10,
#  750: 8,
#  699: 9,
#  1049: 4,
#  372: 14,
#  3740: 1,
#  283: 21,
#  384: 6,
#  443: 5,
#  661: 8,
#  716: 5,
#  471: 11,
#  1297: 2,
#  646: 3,
#  747: 5,
#  146: 16,
#  304: 7,
#  292: 9,
#  877: 4,
#  223: 13,
#  344: 7,
#  1302: 3,
#  1135: 2,
#  563: 4,
#  523: 14,
#  101: 20,
#  937: 4,
#  225: 11,
#  380: 9,
#  324: 12,
#  2985: 1,
#  564: 6,
#  231: 13,
#  5608: 1,
#  264: 12,
#  451: 10,
#  472: 11,
#  378: 16,
#  339: 12,
#  134: 15,
#  226: 11,
#  670: 5,
#  411: 15,
#  454: 9,
#  512: 13,
#  948: 2,
#  597: 4,
#  341: 11,
#  1094: 1,
#  168: 5,
#  103: 9,
#  297: 5,
#  1743: 3,
#  164: 13,
#  1740: 1,
#  586: 6,
#  258: 25,
#  227: 14,
#  94: 13,
#  67: 7,
#  83: 13,
#  536: 9,
#  999: 4,
#  693: 3,
#  349: 18,
#  122: 12,
#  348: 19,
#  494: 8,
#  266: 11,
#  566: 9,
#  636: 2,
#  5451: 1,
#  72: 2,
#  359: 9,
#  8553: 5,
#  367: 9,
#  1949: 1,
#  388: 9,
#  707: 14,
#  528: 2,
#  413: 10,
#  138: 10,
#  824: 8,
#  612: 8,
#  864: 5,
#  1908: 4,
#  669: 7,
#  445: 10,
#  1447: 1,
#  224: 12,
#  113: 28,
#  208: 22,
#  4559: 1,
#  808: 6,
#  3762: 1,
#  3998: 1,
#  19412: 1,
#  3664: 1,
#  1727: 6,
#  90: 12,
#  577: 12,
#  5060: 1,
#  160: 16,
#  580: 9,
#  1981: 3,
#  909: 8,
#  1450: 5,
#  7745: 1,
#  621: 12,
#  86: 10,
#  1398: 1,
#  431: 6,
#  179: 20,
#  525: 10,
#  242: 7,
#  171: 12,
#  249: 8,
#  1642: 3,
#  10740: 1,
#  2316: 4,
#  1354: 1,
#  429: 8,
#  172: 24,
#  4626: 1,
#  990: 8,
#  235: 16,
#  462: 7,
#  481: 8,
#  399: 6,
#  24052: 1,
#  10724: 1,
#  1877: 2,
#  20486: 1,
#  608: 3,
#  1216: 2,
#  2630: 2,
#  441: 14,
#  738: 15,
#  4012: 1,
#  957: 8,
#  2388: 1,
#  871: 5,
#  1610: 1,
#  392: 6,
#  3375: 3,
#  1622: 5,
#  3080: 2,
#  263: 18,
#  1751: 7,
#  1814: 4,
#  1199: 3,
#  422: 10,
#  1561: 8,
#  425: 7,
#  130: 12,
#  1130: 3,
#  879: 6,
#  185: 18,
#  165: 8,
#  587: 10,
#  1496: 3,
#  221: 22,
#  253: 17,
#  193: 16,
#  124: 13,
#  1079: 10,
#  207: 17,
#  159: 29,
#  177: 10,
#  217: 20,
#  456: 9,
#  206: 11,
#  1117: 4,
#  114: 19,
#  5: 14,
#  3: 32,
#  10: 13,
#  147: 8,
#  6: 31,
#  631: 4,
#  369: 11,
#  522: 14,
#  4085: 3,
#  537: 14,
#  261: 13,
#  318: 12,
#  143: 12,
#  3409: 2,
#  2037: 1,
#  95: 10,
#  312: 8,
#  80: 16,
#  1178: 5,
#  3234: 4,
#  62: 25,
#  201: 6,
#  1973: 4,
#  1925: 1,
#  1553: 2,
#  1152: 5,
#  119: 14,
#  712: 4,
#  2379: 1,
#  922: 7,
#  1213: 6,
#  2236: 2,
#  120: 7,
#  1167: 4,
#  4853: 1,
#  761: 2,
#  5004: 2,
#  755: 7,
#  1367: 2,
#  467: 18,
#  2499: 1,
#  97: 20,
#  1258: 3,
#  307: 11,
#  420: 13,
#  61: 20,
#  49: 7,
#  54: 9,
#  855: 4,
#  571: 8,
#  50: 10,
#  51: 9,
#  911: 6,
#  2034: 3,
#  7089: 1,
#  893: 8,
#  1791: 2,
#  93: 13,
#  6151: 4,
#  129: 22,
#  412: 8,
#  1341: 2,
#  282: 15,
#  82: 13,
#  81: 16,
#  144: 17,
#  1438: 1,
#  99: 14,
#  361: 11,
#  153: 10,
#  167: 6,
#  202: 14,
#  358: 4,
#  337: 15,
#  377: 16,
#  354: 5,
#  92: 9,
#  250: 9,
#  291: 12,
#  779: 9,
#  118: 16,
#  107: 13,
#  248: 6,
#  55: 18,
#  1541: 2,
#  5440: 1,
#  1248: 4,
#  53: 18,
#  63: 19,
#  157: 10,
#  76: 11,
#  381: 6,
#  466: 4,
#  5647: 1,
#  1801: 1,
#  6451: 1,
#  658: 9,
#  66: 14,
#  1688: 1,
#  2163: 3,
#  848: 1,
#  1516: 4,
#  213: 16,
#  1403: 4,
#  1096: 2,
#  1095: 2,
#  706: 10,
#  2055: 3,
#  2005: 3,
#  343: 15,
#  364: 11,
#  3379: 1,
#  2284: 2,
#  857: 2,
#  560: 9,
#  924: 4,
#  136: 23,
#  326: 5,
#  810: 4,
#  1635: 2,
#  156: 8,
#  1066: 4,
#  6004: 1,
#  843: 2,
#  930: 4,
#  717: 1,
#  1707: 4,
#  838: 6,
#  1285: 4,
#  662: 6,
#  511: 9,
#  320: 10,
#  827: 4,
#  11035: 2,
#  1029: 6,
#  1466: 5,
#  645: 3,
#  289: 3,
#  2259: 1,
#  1189: 7,
#  254: 10,
#  305: 10,
#  1855: 2,
#  5765: 1,
#  5182: 1,
#  1780: 1,
#  680: 4,
#  106: 15,
#  162: 15,
#  1432: 1,
#  497: 7,
#  1536: 5,
#  766: 2,
#  730: 8,
#  2412: 2,
#  444: 5,
#  568: 6,
#  1745: 2,
#  2256: 2,
#  353: 14,
#  1349: 3,
#  735: 11,
#  1488: 1,
#  1051: 7,
#  725: 7,
#  493: 8,
#  575: 12,
#  279: 14,
#  818: 5,
#  615: 4,
#  521: 11,
#  417: 6,
#  428: 6,
#  52: 16,
#  427: 7,
#  434: 4,
#  709: 16,
#  302: 5,
#  415: 10,
#  927: 6,
#  1163: 4,
#  506: 8,
#  504: 9,
#  394: 9,
#  1084: 2,
#  237: 9,
#  554: 9,
#  2023: 2,
#  538: 19,
#  513: 15,
#  480: 12,
#  677: 5,
#  724: 6,
#  764: 2,
#  375: 16,
#  803: 6,
#  275: 13,
#  410: 11,
#  1728: 4,
#  607: 5,
#  602: 6,
#  3250: 1,
#  346: 18,
#  1143: 3,
#  290: 7,
#  474: 4,
#  1645: 1,
#  1540: 5,
#  2689: 1,
#  4208: 1,
#  1558: 5,
#  784: 1,
#  777: 3,
#  1508: 3,
#  405: 13,
#  2225: 4,
#  3784: 1,
#  495: 7,
#  727: 11,
#  219: 12,
#  7137: 1,
#  2621: 2,
#  903: 5,
#  1257: 5,
#  595: 5,
#  123: 19,
#  1996: 3,
#  2038: 1,
#  4240: 1,
#  42: 23,
#  2984: 1,
#  133: 14,
#  969: 7,
#  1467: 3,
#  2136: 1,
#  48: 13,
#  5956: 3,
#  2579: 1,
#  841: 4,
#  11158: 1,
#  8944: 1,
#  1172: 3,
#  10301: 2,
#  2451: 1,
#  2267: 1,
#  550: 5,
#  16563: 1,
#  277: 10,
#  1179: 6,
#  2255: 5,
#  1218: 2,
#  1200: 4,
#  455: 16,
#  4988: 1,
#  736: 2,
#  2593: 1,
#  421: 13,
#  3339: 1,
#  3062: 2,
#  2804: 1,
#  47: 9,
#  2992: 2,
#  2814: 4,
#  1426: 2,
#  2931: 4,
#  1118: 12,
#  688: 3,
#  1960: 1,
#  21546: 1,
#  2672: 1,
#  10168: 1,
#  2442: 1,
#  50485: 1,
#  831: 4,
#  1195: 3,
#  1700: 3,
#  902: 2,
#  116: 13,
#  192: 10,
#  15341: 1,
#  2906: 1,
#  2884: 1,
#  463: 7,
#  1970: 1,
#  1985: 1,
#  6906: 1,
#  1015: 3,
#  1031: 3,
#  3505: 1,
#  1774: 2,
#  578: 8,
#  659: 5,
#  934: 3,
#  2508: 2,
#  7610: 2,
#  390: 9,
#  1085: 2,
#  1280: 4,
#  2773: 2,
#  203: 15,
#  2268: 1,
#  2491: 1,
#  624: 6,
#  407: 8,
#  2305: 3,
#  2449: 2,
#  1359: 1,
#  1698: 2,
#  1918: 1,
#  867: 6,
#  1793: 3,
#  572: 10,
#  6766: 2,
#  1045: 5,
#  1522: 5,
#  1267: 2,
#  518: 6,
#  2682: 1,
#  2430: 5,
#  11836: 1,
#  1164: 2,
#  996: 4,
#  2018: 4,
#  1930: 5,
#  832: 6,
#  2098: 1,
#  2819: 5,
#  4384: 1,
#  4320: 1,
#  3744: 1,
#  806: 8,
#  11893: 1,
#  633: 6,
#  1899: 2,
#  8917: 1,
#  1064: 3,
#  1419: 3,
#  4195: 2,
#  4307: 1,
#  686: 3,
#  2635: 2,
#  1571: 2,
#  211: 7,
#  4478: 1,
#  1624: 2,
#  190: 9,
#  925: 3,
#  1165: 2,
#  3414: 2,
#  4144: 1,
#  403: 15,
#  1604: 5,
#  2469: 1,
#  2645: 1,
#  4111: 2,
#  2341: 1,
#  1305: 6,
#  3671: 1,
#  752: 4,
#  2202: 1,
#  590: 3,
#  5919: 1,
#  3332: 2,
#  2269: 1,
#  2460: 2,
#  1307: 4,
#  2742: 1,
#  3073: 1,
#  2312: 2,
#  13417: 1,
#  6229: 2,
#  229: 13,
#  1212: 5,
#  960: 3,
#  181: 21,
#  4948: 1,
#  23709: 1,
#  1500: 8,
#  531: 8,
#  792: 5,
#  1940: 3,
#  363: 6,
#  30: 6,
#  1485: 2,
#  ...}

# %%
max(dataProcessor.line_per_spec.values())
# Out:
# 32

# %%
forPlot1 = np.array(sorted(dataProcessor.line_per_spec.items()))

# %%
plt.figure(figsize=(10, 6), dpi=80)
plt.bar(forPlot1[:,0], forPlot1[:,1], color='slateblue')
#plt.hist(data, bins=range(min(data), max(data) + binwidth, binwidth))
#plt.yticks([0,5,10,15,20,25])
plt.xlabel('Number of sentences per specification', fontsize = 14) 
plt.ylabel('Number of occurances',fontsize = 14)
plt.show()

# %%
line_per_spec_list = [key for key, val in dataProcessor.line_per_spec.items() for _ in range(val)]

# %%
plt.figure(figsize=(10, 6), dpi=80)
line_per_spec_list = np.array(line_per_spec_list).astype(int)
binwidth = 1
#plt.hist(line_per_spec_list, bins=np.arange(0, len(line_per_spec_list) + binwidth, binwidth),  color = 'firebrick')
plt.hist(line_per_spec_list, bins=np.arange(0, 1000 + binwidth, binwidth),  color = 'teal')
#plt.hist(data, bins=range(min(data), max(data) + binwidth, binwidth))
plt.yticks([0,5,10,15,20,25,30])
hfont = {'fontname':'Times New Roman'}
plt.xlabel('Number of sentences per specification', fontsize = 14, **hfont) 
plt.ylabel('Number of occurances',fontsize = 14, **hfont)
plt.show()
# Out:
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.

# %%
dataProcessor.spec_per_rel
# Out:
# {'Rel-11': 1214,
#  'Rel-10': 1086,
#  'Rel-9': 1106,
#  'Rel-12': 1281,
#  'Rel-16': 1367,
#  'Rel-13': 1356,
#  'Rel-18': 36,
#  'Rel-19': 1,
#  'Rel-8': 1093,
#  'Rel-14': 1369,
#  'Rel-17': 743,
#  'Rel-15': 1601}

# %%
plot_dict = {}
for key, value in dataProcessor.spec_per_rel.items():
    newKey = int(key[4:])
    plot_dict[newKey] = value

# %%
forPlot2 = np.array(sorted(plot_dict.items()))

# %%
plt.figure(figsize=(7, 5), dpi=80)
plt.bar(forPlot2[:,0], forPlot2[:,1], color='slateblue')
hfont = {'fontname':'Times New Roman'}
plt.xlabel("Release", fontsize = 14, **hfont)
plt.ylabel("# of Specification Document", fontsize = 14, **hfont)
plt.xticks(forPlot2[:,0])
plt.show()

# %% [markdown]
# # Second step

# %%
token_count_vs_sent_count = {} #key: count of token in a sentence, value: number of sentences with that particular count
token_count = []
reduction_count = 0
with open('gold_5G_v5.txt', 'w') as out_file:
    with open(os.path.join(output_path,'processed_5G.txt')) as inp:
        lines = inp.readlines()
        key = 0
        for line in lines:
            if len(line.split())< 4 and line != '\n':
                reduction_count += 1
                continue
            line = re.sub(r' +', ' ', line)
            line = re.sub(r'^ +', '', line)
            if len(line.split()) > 4 and line[-2] != '.':
                line = line[:-2] + '.\n'
            if line[-5:] == 'e.g.\n' or line[-5:] == 'i.e.\n':
                line = line[:-2] + ' '
                reduction_count += 1
            if line == ' ':
                reduction_count += 1
                continue
            key += len(line.split())
            if len(line) > 1 and line[-1] == '\n': #end of a proper line, write in dictionary
                #print('hello')
                token_count.append(key)
                key = 0
#                 if key in token_count_vs_sent_count:
#                     token_count_vs_sent_count[key] += 1 #found another sentence with same count
#                     key = 0
#                 else:
#                     token_count_vs_sent_count[key] = 1 #found first sentence with this count
#                     key = 0
            out_file.write(line)
print("Number of line reduced: ", reduction_count)
# Out:
# Number of line reduced:  1215850

# %%
token_count_vs_sent_count
# Out:
# {}

# %%
plt.bar(list(token_count_vs_sent_count.keys()), token_count_vs_sent_count.values(), color='g')
plt.show()

# %%
token_count = np.array(token_count).astype(int)
binwidth = 0.98
plt.hist(token_count, bins=np.arange(0, 200 + binwidth, binwidth), range = [0,200], color = 'darkslategray')
#plt.hist(data, bins=range(min(data), max(data) + binwidth, binwidth))
plt.xlabel('Number of tokens per sentence', fontsize = 14) 
plt.ylabel('Number of occurances',fontsize = 14)
plt.show()

# %%
viz_file1 = "./viz/sen_per_spec.npy"
viz_file2 = "./viz/doc_per_rel.npy"
viz_file3 = "./viz/tok_per_sen.npy"
with open(viz_file1, 'wb') as f:
    np.save(f, line_per_spec_list)

with open(viz_file2, 'wb') as f:
    np.save(f, forPlot2)

with open(viz_file3, 'wb') as f:
    np.save(f, token_count)

# %% [markdown]
# ### Random Testing

# %%
re.sub(r' +',' ','·         Periodic TAU: Upon the expiry of timer T3412, periodic TAU procedure is initiated to periodically notify the availability of the UE to the network')

# %%
files = glob.glob(parent_path + '/**/*.txt', recursive=True)
files

# %%
re.sub(r'([,;:])(\w)', r'\1 \2', 'Periodic TAU:Upon the expiry of timer T3412,periodic TAU procedure.Hello' )

# %%
re.sub(r'[(\(\))(\[\])(\{\})]', '', 'Periodic TAU:Upon the expiry of timer T3412,periodic TAU procedure. () Hello {eh}')

# %%
re.sub(r'(el)|(fo)', '', 'Periodic TAU:Upon the expiry of timer T3412, periodic TAU procedure.Hello elfo')

# %%
re.sub(r'[el]', '', 'Periodic TAU:Upon the expiry of timer T3412, periodic TAU procedure.Hello elfo')

# %%
re.sub(r'[\.:,;\-]*$', '', 'Per..iodic TAU:Upon th.e..;')

# %%
'Per..iodic TAU:Upon th.e..;'+'.'

# %%
print('\ue300')

# %%
os.path.exists('gold_5G.txt')

# %%
line = 'Periodic TAU:Upon the expiry of timer T3412,periodic TAU procedure. )() Hello {eh}'

# %%
code_ident = ["((", "))", "{{", "}}",  "[[",  "]]",  "::", ":="]
if any(x in line for x in code_ident):
    print('hello')

# %%
re.sub('Figure .*?[\dA-Za-z]:', '', 'Figure 3.1-1B: C: Examples of: ports for 3: BS F.1B: type 1-C and BS type 1-H')

# %%
re.sub('\(see [fF]igure .*?\d\)', '', 'is the Transmission Bandwidth for kth allocated component carrier (see Figure 5.3.3-1) hello 5) (see Figure 5.3.3)')

# %%
re.sub(r'\[\d*?\]', '', 'is the Transmission [5]Bandwidth [62] for kth [3] 4] allocated')

# %%
re.sub(r'(\d[A-Za-z]*\.)*\d[\.\-]\d?', '', 'As shown in Figure 7V.3.2B.2.2-1, TS 24.301 transmission of section 4-1 Figure A-1 uplink frame Figure B.1.1.4.4-1 number [pic], Figure 7.3.2.2.2.1 hello')

# %%
line = 'ahbda uadvb TS'
line[-2:]

# %%
re.sub(r'^\d.*', '', '2 As shown in Figure 7V.3.2B.2.2-1, transmission of section 4-1 Figure A-1 uplink frame Figure B.1.1.4.4-1 number [pic], Figure 7.3.2.2.2.1 hello')

# %%
'TS |TR |'

# %%
re.sub(r'(\t)+', ' ', 'As shown in \t\tFigure \t')

# %%
re.sub(r'\\x[0-9a-fA-F]{2}', '', r'As shown \xc0\xa1\x1e in \t\tFigure \t')

# %%
'As shown\ in\t \\\xe0 Figure'

# %%
re.sub(r'(\\)+', r'\\', 'As shown\ in\\t \\\xe0 Figure')

# %%
re.sub(r'(\t)+', ' ', 'As shown in\\\t \\\ Figure')

# %%
r1 = re.findall(r"^\w+", xx)

# %%
len(re.search(r"\b[A-Z]*", 'HELLo me')[0])

# %%
line = 'aEro Me'
line.istitle()

# %%
sen = 'hello crow \\t'
if '\\' in sen:
    print('yes')

# %%
re.sub(r' +', ' ', 'hello  \n   from the other side')

# %%
re.sub(r'(\(\))|(\[\])|(\{\})', '', 'hello   (from) the other side' )

# %%
a = 'hello . world '
a.split('. ')

# %%
re.sub(r'(\d[A-Za-z]?\.)*\d[\.\-]\d?', '', 'section 4.3.2.1 says 3.2a that its 5.3a.2.2 3.1.d.e TS 24.301')

# %%
if re.search(r'(C\(\d\d\d\))', "hello C(459)"):
    print("meh")

# %%
r'(C\(\d\d\d\))' in "hello C(459)"

# %%
if re.match(r'(C\(\d\d\d\))', 'hello C(123)'):
    print("hell")

# %%
re.sub(r'(TS \d\d\d)|(TR \d\d\d)', 'specification document', 'TS 240 suggests')

# %%
re.sub(r'^(TS \d\d\d)|^(TR \d\d\d)', 'Specification document', 'TS 240 suggests TR 341')

# %%
re.search(r'% %', 'alu %% % % % potol')

# %%
my = 'what the docu e.g.\n'
my[-5:]

# %%
my =' degree  AOA_ANGLE _001 \(AOA_ANGLE < 1 degree  AOA_ANGLE _002 1 \(AOA_ANGLE < degree  AOA_ANGLE _717 35 \(AOA_ANGLE < 359 degre'
sum(c.isdigit() for c in my)/len(my)

# %%
if '<img' in 'The overall presentation is governed by the SMIL file located as the primary item of "presentation.3gp" <region id="pics" left="0" width="176" height="144"/> <img region="pics" src="picjpg" dur="3s"/> <img region="pics" src="picjpg" dur="3s"/> <img region="pics" src="picjpg" dur="3s"/> The audio track resides in the Movie box and is referred to as "#box=moov" whereas the images are included as media files in the Meta box The following example consists of a DIMS presentation that refers to images, an AMR clip and scene updates.':
    print("hello")

# %%
re.search(r'-?\d,? -?\d,? -?\d', '-a1, -1 1 1 1, 1 abcd efg')

# %%
re.sub(r'(TS \d\d\d?)|(TR \d\d\d?)', 'Specification document', 'TS 24 suggests TR 341')

# %%
"/scratch/gilbreth/rahman75/raw_data/Rel-10/21_series/21101-a40/21101-a40.txt".split('/')[5][:3]

# %%
'/home/rahman75/Scrap/Dataset_L1/Data_4G/3glteinfo/ab.txt'.split('/')[-4]

# %%
'/scratch/gilbreth/rahman75/raw_data/web_data/Cellular Dataset/eventhelix/ab.txt'.split('/')[5][:3]

# %%
'\n\ta'.split()
